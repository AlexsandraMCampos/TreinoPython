# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexsandraMCampos/TreinoPython/blob/main/Operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Operadores

# %% [markdown]
# ## Operadores Aritméticos

# %%
x = 2 + 5 * 3
print(x)
# Out:
# 17

# %%
x =(1 + 2)**3
print(x)
# Out:
# 27

# %% [markdown]
# # Exercícios

# %%
x = 6 + 4 * 2
print(x)
# Out:
# 14

# %%
x =(4 * 9 + 5)
print(x)
# Out:
# 41

# %%
x=((6 + 7)* 9)
print (x)
# Out:
# 117

# %%
x=(15 + 20 - 30)
print(x)
# Out:
# 5

# %%
x=(6 + 5 **2)
print(x)
# Out:
# 31

# %% [markdown]
# ## Operadores de Atribuição

# %%
x =8
x +=5 # incremenda +5 ao valor de x
print (x)
# Out:
# 13

# %%
x =8
x*=5 # neste caso o incrmente e multiplicar o x por 5
print(x)
# Out:
# 40

# %%
x =8
x-= 4
print(x)
# Out:
# 4

# %%
x =8
x*=20
print(x)
# Out:
# 160

# %% [markdown]
# # Exercícios

# %%
x=8
x+=5
print(x)
# Out:
# 13

# %%
x=8
x-=4
print(x)
# Out:
# 4

# %%
x=8
x*=20
print(x)
# Out:
# 160

# %%
x=8
x/=2
print(x)
# Out:
# 4.0

# %% [markdown]
# ## Operadores de Comparação

# %% [markdown]
# # = significa atribuição
# # == igual a
# # === comparação e tipo

# %%
x = 8
x1 = 3
xresultado = x < x1
print(xresultado)
# Out:
# False

# %% [markdown]
# ## Exercícios

# %%
x = 8
x1 = 3
xresult = x < x1
print(xresult)
# Out:
# False

# %%
xresult = x == x1
print(xresult)
# Out:
# False

# %%
xresult = x>= x1
print(xresult)
# Out:
# True

# %%
xresult = x != x1
print(xresult)
# Out:
# True

# %% [markdown]
# # Operadores Lógicos

# %% [markdown]
# # and = &&
# # or =
# # not = !

# %%
idade_Kaique = 30
idade_Jessica = 24
not (idade_Kaique >= 18 and idade_Jessica >= 18)
# Out:
# False

# %% [markdown]
# ## Operadores de Idetidade

# %% [markdown]
# # is
# # is not

# %%
x = "Caique"
x1 = "Jessica"
x2 = "Caique"
xresultado = x is not x2
print(xresultado)
# Out:
# False

# %% [markdown]
# ## Exercícios

# %%
x1 = "botafogo"
x2 ="flamengo"
x3 = "botafogo"
xresult = x is x3
print(xresult)
# Out:
# True

# %%
xresult = x1 is not x2
print(xresult)
# Out:
# True

# %%
xresult = x1 is x3
print(xresult)
# Out:
# True

# %%
xresult = x2 is not x3
print(xresult)
# Out:
# True
