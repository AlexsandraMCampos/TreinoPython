# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexsandraMCampos/TreinoPython/blob/main/EstruturaDeDecisao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estrutura de Decisão

# %%
# Verificar se aidade e maior que 18 anos
idade = 18
if idade >= 18:
  print("Maior de idade")
# Out:
# Maior de idade

# %%
# Verificar se o número é positivo
n1 = 4
if n1 > 0:
  print("Este número é positivo")
# Out:
# Este número é positivo

# %% [markdown]
# 3. Número par
# Peça um número ao usuário e exiba &quot;Número par&quot; se ele for divisível
# por 2.

# %%
num = 4
if num % 2 == 0:
  print("Este", num ,"é positivo.")
# Out:
# Este 4 é positivo.

# %% [markdown]
# 4. Verificação de temperatura
# Se a temperatura informada pelo usuário for maior que 30°C, exiba
# &quot;Está quente!&quot;.

# %%
temperatura = float(input("Informe a temperatura : "))
if temperatura >30:
  print("O dia estã muito quente !")
# Out:
# Informe a temperatura : 38
# O dia estã muito quente !

# %% [markdown]
# 5. Nota mínima para aprovação
# Se a nota de um aluno for maior ou igual a 6, exiba &quot;Aprovado&quot;.

# %%
nota = int(input("Informe sua nota: "))
if nota >= 6:
  print("Você está aprovado!")
# Out:
# Informe sua nota: 7
# Você está aprovado!

# %% [markdown]
# 6. Verificação de senha
# Se a senha digitada pelo usuário for &quot;1234&quot;, exiba &quot;Acesso permitido&quot;.

# %%
senha = str(input("Digite sua senha: ")) # str nao precisa ser declarada anteriormente
if senha == "1234":
  print("Acesso permitido.")
# Out:
# Digite sua senha: 1234
# Acesso permitido.

# %% [markdown]
# 7. Desconto em compras
# Se o valor da compra for maior que R$100,00, exiba &quot;Você ganhou um
# desconto!&quot;.

# %%
compra = float(input("Informe o valor da sua compra:"))
if compra > 100:
  print("Você ganhou um desconto !")
# Out:
# Informe o valor da sua compra:250.00
# Você ganhou um desconto !

# %% [markdown]
# 8. Número maior que 100
# Peça um número ao usuário e exiba &quot;Número maior que 100&quot; se ele for
# maior que 100.

# %%
num = int(input("Informe um número:"))
if num > 100:
  print("O número", num, "é maior que 100.")
# Out:
# Informe um número:200
# O número 200 é maior que 100.

# %% [markdown]
# 9. Velocidade do carro
# Se a velocidade informada for maior que 80 km/h, exiba &quot;Você foi
# multado!&quot;.

# %%
velocidade = float(input("Informe a velocidade do carro: "))
if velocidade > 80:
  print("Você ultrapassou o limite de velocidade, estava dirigindo a ", velocidade,"Km/h e foi multado.")
# Out:
# Informe a velocidade do carro: 95
# Você ultrapassou o limite de velocidade, estava dirigindo a  95.0 Km/h e foi multado.

# %% [markdown]
# 10. Ano bissexto
# Se o ano informado for divisível por 4, exiba &quot;Ano bissexto&quot;.

# %%
ano = int(input("Informe o ano: "))
if ano % 4 == 0:
  print("O ano", ano, "é bissexto.")
# Out:
# Informe o ano: 2024
# O ano 2024 é bissexto.
