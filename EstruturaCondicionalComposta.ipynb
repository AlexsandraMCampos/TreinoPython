# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexsandraMCampos/TreinoPython/blob/main/EstruturaCondicionalComposta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Esturuta de decisão composta

# %%
idade = int(input("Digite sua idade: "))
if idade >= 18:
  print("Sua idade é", idade, " e você é maior de idade.")
else:
  print("Sua idade é" , idade, " e você é menor de idade.")
# Out:
# Digite sua idade: 14
# Sua idade é 14 você é menor de idade.

# %%
num = int(input("Digite um número inteiro: "))
if num % 2 == 0:
  print(" O número", num, "é par." )
else:
  print(" O número", num, "é ímpar." )
# Out:
# Digite um número inteiro: 7
#  O número 7 é ímpar.

# %%
senha = str(input("Digite sua senha: "))
if senha == "1234":
  print("Seu acesso está liberado.")
else:
  print("Digitou senha errada e seu acesso não é permitido.")
# Out:
# Digite sua senha: 234
# Digitou senha errada e seu acesso não é permitido.

# %%
dia = str(input("Informe o dia da semana: ")).upper().strip()
if dia == "sábado"or dia == "sabado" or dia =="domingo":
  print("Hoje é", dia, "aproveite o final de semana.")
else:
  print("Hoje é", dia, "aproveite seu dia.")
# Out:
# Informe o dia da semana: segunda
# Hoje é SEGUNDA aproveite seu dia.

# %%
## Exercícios

# %% [markdown]
# 1. Verificação de números diferentes
# Peça dois números ao usuário. Se forem diferentes, exiba &quot;Os números
# são diferentes&quot;, caso contrário, exiba &quot;Os números são iguais&quot;.

# %%
num1 = int(input("Digite um número: "))
num2 = int(input("Digite um novo número: "))

if num1 != num2:
  print("Os números", num1, "e", num2, "são diferentes.")
# Out:
# Digite um número: 5
# Digite um novo número: 6
# Os números 5 e 6 são diferentes.

# %% [markdown]
# 2. Verificação de maioridade
# Solicite a idade do usuário e informe se ele é maior de idade (18 anos ou
# mais) ou menor de idade.

# %%
idade = int(input("Digite sua idade: "))
if idade >= 18:
  print("Sua idade é", idade, " e você é maior de idade.")
else:
  print("Sua idade é" , idade, " e você é menor de idade.")
# Out:
# Digite sua idade: 34
# Sua idade é 34  e você é maior de idade.

# %% [markdown]
# 3. Autorização de entrada em um evento
# Se a pessoa tiver um convite válido, exiba &quot;Entrada permitida&quot;, caso
# contrário, exiba &quot;Entrada negada&quot;.

# %%
senha = str(input("Digite sua senha: ")).upper().strip()
if senha == "vip":
  print("Entrada permitida.")
else:
  print("Sua senha é inválida.")
# Out:
# Digite sua senha: vip
# Sua senha é inválida.

# %% [markdown]
# 4. Verificação de nome em lista
# Peça um nome ao usuário. Se for &quot;Carlos&quot;, exiba &quot;Você está na lista&quot;,
# senão, exiba &quot;Nome não encontrado&quot;.

# %%
nome = str(input("Informe seu nome: ")).upper().strip()
if nome == "Carlos":
  print("Você está na lista.")
else:
  print("Infelizmente, você não está na lista.")

# %% [markdown]
# 5. Cálculo de gorjeta
# Peça o valor da conta. Se for maior que R$100,00, adicione uma gorjeta
# de 10% e exiba o total a pagar. Caso contrário, adicione uma gorjeta de
# 5%.

# %%
conta = float(input("Informe o valor da conta: "))
if conta >= 100:
  conta *=1.10
  print("Total a pagar R$", conta)
else:
  conta*=1.05
  print("Total a pagar R$", conta)
# Out:
# Informe o valor da conta: 120
# Total a pagar R$ 132.0

# %% [markdown]
# 6. Acesso ao Wi-Fi
# Peça a senha do Wi-Fi ao usuário. Se for &quot;senha123&quot;, exiba
# &quot;Conectado&quot;, caso contrário, exiba &quot;Senha incorreta&quot;.

# %%
senha = str(input("Digite sua senha: ")).strip()
if senha == "senha123":
  print("Conectado.")
else:
  print("Senha Incorreta.")
# Out:
# Digite sua senha: senha123
# Conectado.

# %% [markdown]
# 7. Verificação de turno
# Peça ao usuário para digitar &quot;M&quot; para manhã ou qualquer outra tecla
# para tarde. Se for &quot;M&quot;, exiba &quot;Bom dia!&quot;, senão exiba &quot;Boa tarde!&quot;.

# %%
turno = str(input("Digite seu turno: ")).strip()
if turno == "M" or turno == "manhã":
  print("Bom dia!")
else:
  print("Boa tarde!.")
# Out:
# Digite seu turno: tarde
# Boa tarde!.

# %% [markdown]
# 8. Verificação de múltiplo de 5
# Peça um número ao usuário e verifique se ele é múltiplo de 5. Se for,
# exiba &quot;Múltiplo de 5&quot;, senão exiba &quot;Não é múltiplo de 5&quot;.

# %%
num = int(input("Digite um número: "))
if num % 5 == 0:
  print("O número ",num, "é múltiplo de 5.")
else:
  print("O número ",num, "não é múltiplo de 5.")
# Out:
# Digite um número: 20
# O número  20 é múltiplo de 5.

# %% [markdown]
# 9. Desconto em compras por valor mínimo
# Se o valor da compra for maior que R$150,00, aplique um desconto de
# R$20,00. Caso contrário, não aplique desconto.

# %%
compra = float(input("Informe o valor da compra: "))
if compra >= 150:
  compra -=20
  print("Total a pagar R$", compra)
else:
   print("Total a pagar R$", compra)
# Out:
# Informe o valor da compra: 70
# Total a pagar R$ 70.0
